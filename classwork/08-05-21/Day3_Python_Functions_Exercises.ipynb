# %% [markdown]
# <img src="https://i.imgur.com/X9R3e67.png" style="float: left; margin: 20px; height: 55px">
#
# ## Practice Python Functions
#
#
# ---

# %%
# def printMyName():
#   user_name = input("Whats your name? ")
#   return user_name


# printMyName()


def printMyName(lastname): #name should be a string
  firstname = input("What is your first name? ")
  return firstname + lastname

printMyName(" Deodutt")
# Out:
# What is your first name? ricardo
# 'ricardo Deodutt'

# %% [markdown]
# ### Resources - Potentially Helpful Functions
#
# * [Python exercises](https://learnpythonthehardway.org/book/)
# * [Dictionary Comprehension](https://docs.python.org/2/tutorial/datastructures.html#dictionaries)
# * [Enumerate](https://docs.python.org/2/library/functions.html#enumerate)
# * [Length](https://docs.python.org/2/library/functions.html#len)
# * [Int](https://docs.python.org/2/library/functions.html#int)
# * [List](https://docs.python.org/2/library/functions.html#list)

# %% [markdown]
# ---
#
# ### 1. Write a function that takes the length of a side of a square as an argument and returns the area of the square.

# %%
def lengthCalc(side):
  return side**2

lengthCalc(20)
# Out:
# 400

# %% [markdown]
# ---
#
# ### 2. Write a function that takes the heigth and width of a triangle and returns the area.

# %%
def areaTriangle(height, width):
  return 0.5 * height * width

print(areaTriangle(10, 10))
# Out:
# 50.0

# %% [markdown]
# ---
#
# ### 3. Write a function that takes a string as an argument and returns a tuple consisting of two elements:
# - **A list of all the characters in the string.**
# - **A count of the number of characters in the string.**

# %%
def stringConvert(string_argument):
    tuples = []
    charCount = len(string_argument)

    for x in string_argument:
        tuples += x
    # print(f"{tuples} {charCount}")   #had this before but it printed out None at the bottom. You gotta return.
    return (tuples, charCount)


print(stringConvert("Python"))
# Out:
# (['P', 'y', 't', 'h', 'o', 'n'], 6)

# %% [markdown]
# ---
#
# ### 4. Write a function that takes two integers, passed as strings, and returns the sum, difference, and product as a tuple (all values as integers).

# %%
def stringCalc(x, y):
    x = int(x)
    y = int(y)
    totalSum = x + y
    totalDifference = x / y
    totalProduct = x * y
    return (totalSum, totalDifference, totalProduct)


# print(stringCalc("2 3 1"))
print(stringCalc("10", "2"))
# Out:
# (12, 5.0, 20)

# %% [markdown]
# ---
#
# ### 5. Write a function that takes a list as the argument and returns a tuple consisting of two elements:
# - **A list with the items in reverse order.**
# - **A list of the items in the original list that have an odd index.**

# %%
def listConvert(inputed_list):
    copied_list = inputed_list.copy()
    copied_list.reverse()

    length_index = len(inputed_list)
    oddIndex = []
    for x in range(length_index):
        if x % 2 == 0:
            oddIndex.append(inputed_list[x])


    return (copied_list, oddIndex)

# print(reversedList)
listConvert([1, 2, 3, 4, 5, 6, 7])
# Out:
# ([7, 6, 5, 4, 3, 2, 1], [1, 3, 5, 7])

# %% [markdown]
# ---
#
# ### Optional Challenge Problem: Write a function that returns the score for a word.  The score of the word is the sum of the scores of its letters. Each letter's score is equal to it's position in the alphabet.
#
# So, for example:
#
# * A = 1, B = 2, C = 3, D = 4, E = 5
# * abe = 8 = (1 + 2 + 5)
#
#
# _Hint: The string library has a property_ `ascii_lowercase` _that can save some typing here._

# %%
# A:
# Out:
# [3, 2, 1]
